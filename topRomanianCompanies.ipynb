# %%
import pandas as pd

companies = pd.read_html("https://en.wikipedia.org/wiki/List_of_largest_European_companies_by_revenue")[0]
companies
# Out:
#      Rank                       Company            Industry  \
# 0       1                         Shell         Oil and gas
# 1       2                            BP         Oil and gas
# 2       3                    Volkswagen          Automotive
# 3       4                   Vitol Group         Oil and gas
# 4       5                      Glencore        Conglomerate
# ..    ...                           ...                 ...
# 155   156                           KfW  Financial services
# 156   157                   Bertelsmann          Mass media
# 157   158  International Airlines Group            Aviation
# 158   159                        Sodexo       Food services
# 159   160                 National Grid    Electric utility
#
#      Revenue (US$ Billion)                    Headquarters  Founded
# 0                  344.900  United Kingdom and Netherlands   1907.0
# 1                  282.620                  United Kingdom   1908.0
# ...
